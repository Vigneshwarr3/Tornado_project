# %%
import pandas as pd 
import matplotlib.pyplot as plt 

df = pd.read_csv("1950-2023_all_tornadoes.csv")
df.head()
# Out:
#     om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  wid  \
# 0  192  1950  10   1  1950-10-01  21:00:00   3  OK   40   23  ...  15.8   10
# 1  193  1950  10   9  1950-10-09  02:15:00   3  NC   37    9  ...   2.0  880
# 2  195  1950  11  20  1950-11-20  02:20:00   3  KY   21    1  ...   0.1   10
# 3  196  1950  11  20  1950-11-20  04:00:00   3  KY   21    2  ...   0.1   10
# 4  197  1950  11  20  1950-11-20  07:30:00   3  MS   28   14  ...   2.0   37
#
#    ns  sn  sg   f1  f2  f3  f4  fc
# 0   1   1   1   25   0   0   0   0
# 1   1   1   1   47   0   0   0   0
# 2   1   1   1  177   0   0   0   0
# 3   1   1   1  209   0   0   0   0
# 4   1   1   1  101   0   0   0   0
#
# [5 rows x 29 columns]

# %%
list(df.columns)
# Out:
# ['om',
#  'yr',
#  'mo',
#  'dy',
#  'date',
#  'time',
#  'tz',
#  'st',
#  'stf',
#  'stn',
#  'mag',
#  'inj',
#  'fat',
#  'loss',
#  'closs',
#  'slat',
#  'slon',
#  'elat',
#  'elon',
#  'len',
#  'wid',
#  'ns',
#  'sn',
#  'sg',
#  'f1',
#  'f2',
#  'f3',
#  'f4',
#  'fc']

# %%
max_len = df.groupby('yr')['len'].max().reset_index()

print(max_len)
max_len.to_csv('max_len.csv',index = False)

plt.figure(figsize=(8, 6))

plt.plot(max_len['yr'], max_len['len'], color='blue')

plt.title('Line plot of Year vs Maximum length')
plt.xlabel('yr')
plt.ylabel('max_len')
plt.show()
# Out:
#       yr     len
# 0   1950   82.60
# 1   1951  112.80
# 2   1952  104.80
# 3   1953  234.70
# 4   1954  139.90
# ..   ...     ...
# 69  2019   68.04
# 70  2020   83.22
# 71  2021  168.53
# 72  2022   70.57
# 73  2023  125.76
#
# [74 rows x 2 columns]
